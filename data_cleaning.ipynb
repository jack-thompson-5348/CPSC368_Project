# %% [markdown]
# ## Data Cleaning

# %%
# imports
import pandas as pd

# %%
# reading the data
data_2022 = pd.read_csv("RawData/data_22.csv")
data_2023 = pd.read_csv("RawData/data_23.csv")
data_2024 = pd.read_csv("RawData/data_24.csv")

# %% [markdown]
# ### 2022 Data

# %%
# look at number of rows and columns
data_2022.shape
# Out:
# (646, 17)

# %%
# list all columns
data_2022.columns.tolist()
# Out:
# ['uri',
#  'artist_names',
#  'track_name',
#  'peak_rank',
#  'weeks_on_chart',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'tempo',
#  'time_signature',
#  'duration_ms']

# %%
# keep only required columns
data_2022 = data_2022[[
    "uri",
    "track_name",
    "artist_names",
    "peak_rank",
    "weeks_on_chart",
    "danceability",
    "energy",
    "key",
    "loudness",
    "mode",
    "speechiness",
    "acousticness",
    "tempo"
]]
data_2022 = data_2022.rename(columns={"key": "music_key", "mode": "music_mode"})

# %%
# look at the dataset high-level
data_2022.head()
# Out:
#                                     uri  \
# 0  spotify:track:02MWAaffLxlfxAUY7c5dvx
# 1  spotify:track:5PjdY0CKGZdEuoNab3yDmX
# 2  spotify:track:3IAfUEeaXRX9s9UdKOJrFI
# 3  spotify:track:1HhNoOuqm1a5MXYEgAFl8o
# 4  spotify:track:4fouWK6XVHhzl78KzQ1UjL
#
#                                           track_name  \
# 0                                         Heat Waves
# 1                          STAY (with Justin Bieber)
# 2                                           Envolver
# 3  Enemy (with JID) - from the series Arcane Leag...
# 4                                            abcdefu
#
#                                       artist_names  peak_rank  weeks_on_chart  \
# 0                                    Glass Animals          1              65
# 1                     The Kid LAROI, Justin Bieber          1              37
# 2                                           Anitta          3               3
# 3  Imagine Dragons, JID, Arcane, League of Legends          3              21
# ...

# %%
# check data types and if null values are allowed
data_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 646 entries, 0 to 645
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   uri             646 non-null    object
#  1   track_name      646 non-null    object
#  2   artist_names    646 non-null    object
#  3   peak_rank       646 non-null    int64
#  4   weeks_on_chart  646 non-null    int64
#  5   danceability    646 non-null    float64
#  6   energy          646 non-null    float64
#  7   music_key       646 non-null    int64
#  8   loudness        646 non-null    float64
#  9   music_mode      646 non-null    int64
#  10  speechiness     646 non-null    float64
#  11  acousticness    646 non-null    float64
#  12  tempo           646 non-null    float64
# dtypes: float64(6), int64(4), object(3)
# memory usage: 65.7+ KB

# %%
# null values are not allowed but to check
data_2022.isnull().sum()
# Out:
# uri               0
# track_name        0
# artist_names      0
# peak_rank         0
# weeks_on_chart    0
# danceability      0
# energy            0
# music_key         0
# loudness          0
# music_mode        0
# speechiness       0
# acousticness      0
# tempo             0
# dtype: int64

# %% [markdown]
# #### standardising 2022 data types

# %%
# Clean text columns
text_cols_2022 = ["uri", "artist_names", "track_name"]

for col in text_cols_2022:
    data_2022[col] = data_2022[col].astype("string")

# Integer columns
int_cols_2022 = ["peak_rank", "weeks_on_chart", "music_key", "music_mode",]

for col in int_cols_2022:
    data_2022[col] = pd.to_numeric(data_2022[col], errors="coerce").astype("Int64")

# Float columns
float_cols_2022 = ["danceability", "energy", "loudness", "speechiness", "acousticness", "tempo"]

for col in float_cols_2022:
    data_2022[col] = pd.to_numeric(data_2022[col], errors="coerce")

# give key numbers their actual key values
key_map = {
0:"C",1:"C#",2:"D",3:"D#",4:"E",
5:"F",6:"F#",7:"G",8:"G#",9:"A",10:"A#",11:"B"
}

data_2022["music_key"] = data_2022["music_key"].map(key_map)

# same for Major or Minor
mode_map = {1:"Major",0:"Minor"}
data_2022["music_mode"] = data_2022["music_mode"].map(mode_map)

# convert them into string
data_2022["music_key"] = data_2022["music_key"].astype("string")
data_2022["music_mode"] = data_2022["music_mode"].astype("string")

# Check result
data_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 646 entries, 0 to 645
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   uri             646 non-null    string
#  1   track_name      646 non-null    string
#  2   artist_names    646 non-null    string
#  3   peak_rank       646 non-null    Int64
#  4   weeks_on_chart  646 non-null    Int64
#  5   danceability    646 non-null    float64
#  6   energy          646 non-null    float64
#  7   music_key       646 non-null    string
#  8   loudness        646 non-null    float64
#  9   music_mode      646 non-null    string
#  10  speechiness     646 non-null    float64
#  11  acousticness    646 non-null    float64
#  12  tempo           646 non-null    float64
# dtypes: Int64(2), float64(6), string(5)
# memory usage: 67.0 KB

# %% [markdown]
# ### 2023 Data

# %%
# repeat the same process for 2023 dataset
data_2023.shape
# Out:
# (953, 24)

# %%
# check columns
data_2023.columns.tolist()
# Out:
# ['track_name',
#  'artist(s)_name',
#  'artist_count',
#  'released_year',
#  'released_month',
#  'released_day',
#  'in_spotify_playlists',
#  'in_spotify_charts',
#  'streams',
#  'in_apple_playlists',
#  'in_apple_charts',
#  'in_deezer_playlists',
#  'in_deezer_charts',
#  'in_shazam_charts',
#  'bpm',
#  'key',
#  'mode',
#  'danceability_%',
#  'valence_%',
#  'energy_%',
#  'acousticness_%',
#  'instrumentalness_%',
#  'liveness_%',
#  'speechiness_%']

# %%
# remove columns which are not required, keep only required
data_2023 = data_2023[[
    "track_name",
    "artist(s)_name",
    "streams",
    "bpm",
    "key",
    "mode",
    "danceability_%",
    "valence_%",
    "energy_%",
    "acousticness_%",
    "instrumentalness_%",
    "liveness_%",
    "speechiness_%"
]]
data_2023 = data_2023.rename(columns = {"key":"music_key","mode":"music_mode"})

# %%
data_2023.head()
# Out:
#                             track_name    artist(s)_name    streams  bpm  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook  141381703  125
# 1                                 LALA       Myke Towers  133716286   92
# 2                              vampire    Olivia Rodrigo  140003974  138
# 3                         Cruel Summer      Taylor Swift  800840817  170
# 4                       WHERE SHE GOES         Bad Bunny  303236322  144
#
#   music_key music_mode  danceability_%  valence_%  energy_%  acousticness_%  \
# 0         B      Major              80         89        83              31
# 1        C#      Major              71         61        74               7
# 2         F      Major              51         32        53              17
# 3         A      Major              55         58        72              11
# 4         A      Minor              65         23        80              14
#
#    instrumentalness_%  liveness_%  speechiness_%
# ...

# %%
data_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   track_name          953 non-null    object
#  1   artist(s)_name      953 non-null    object
#  2   streams             953 non-null    object
#  3   bpm                 953 non-null    int64
#  4   music_key           858 non-null    object
#  5   music_mode          953 non-null    object
#  6   danceability_%      953 non-null    int64
#  7   valence_%           953 non-null    int64
#  8   energy_%            953 non-null    int64
#  9   acousticness_%      953 non-null    int64
#  10  instrumentalness_%  953 non-null    int64
#  11  liveness_%          953 non-null    int64
#  12  speechiness_%       953 non-null    int64
# dtypes: int64(8), object(5)
# memory usage: 96.9+ KB

# %%
data_2023.isnull().sum()
# Out:
# track_name             0
# artist(s)_name         0
# streams                0
# bpm                    0
# music_key             95
# music_mode             0
# danceability_%         0
# valence_%              0
# energy_%               0
# acousticness_%         0
# instrumentalness_%     0
# liveness_%             0
# speechiness_%          0
# dtype: int64

# %% [markdown]
# #### standardize 2023 data types

# %%
# Rename artist column to match other datasets
data_2023 = data_2023.rename(columns={
    "artist(s)_name": "artist_names"
})

# Clean text columns
text_cols_2023 = ["track_name", "artist_names", "music_key", "music_mode"]

for col in text_cols_2023:
    data_2023[col] = data_2023[col].astype("string")

# Clean and convert streams safely
data_2023["streams"] = (
    data_2023["streams"]
    .astype("string")
    .str.replace(",", "", regex=False)
    .str.strip()
)

data_2023["streams"] = pd.to_numeric(data_2023["streams"], errors="coerce")

# Drop rows where streams is invalid/missing
data_2023 = data_2023.dropna(subset=["streams"])

# Now convert to integer
data_2023["streams"] = data_2023["streams"].astype("int64")

# Numeric columns
numeric_cols_2023 = [
    "bpm",
    "danceability_%",
    "valence_%",
    "energy_%",
    "acousticness_%",
    "instrumentalness_%",
    "liveness_%",
    "speechiness_%"
]

for col in numeric_cols_2023:
    data_2023[col] = pd.to_numeric(data_2023[col], errors="coerce")

# Convert percentage columns to decimals to match 2022 dataset
cols_pct = [
    "danceability_%",
    "valence_%",
    "energy_%",
    "acousticness_%",
    "instrumentalness_%",
    "liveness_%",
    "speechiness_%"
]

data_2023[cols_pct] = data_2023[cols_pct] / 100

# Rename columns so they match 2022 naming
data_2023 = data_2023.rename(columns={
    "danceability_%": "danceability",
    "valence_%": "valence",
    "energy_%": "energy",
    "acousticness_%": "acousticness",
    "instrumentalness_%": "instrumentalness",
    "liveness_%": "liveness",
    "speechiness_%": "speechiness"
})

# Keep key and mode as cleaned text
data_2023["music_key"] = data_2023["music_key"].replace("nan", pd.NA)
data_2023["music_mode"] = data_2023["music_mode"].replace("nan", pd.NA)

# Check result
data_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 952 entries, 0 to 952
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_name        952 non-null    string
#  1   artist_names      952 non-null    string
#  2   streams           952 non-null    int64
#  3   bpm               952 non-null    int64
#  4   music_key         857 non-null    string
#  5   music_mode        952 non-null    string
#  6   danceability      952 non-null    float64
#  7   valence           952 non-null    float64
#  8   energy            952 non-null    float64
#  9   acousticness      952 non-null    float64
#  10  instrumentalness  952 non-null    float64
#  11  liveness          952 non-null    float64
#  12  speechiness       952 non-null    float64
# dtypes: float64(7), int64(2), string(4)
# memory usage: 104.1 KB

# %% [markdown]
# #### Fix the 2023 artist column name so it matches too

# %%
data_2023 = data_2023.rename(columns={
    "artist(s)_name": "artist_names"
})

data_2023.columns
# Out:
# Index(['track_name', 'artist_names', 'streams', 'bpm', 'music_key',
#        'music_mode', 'danceability', 'valence', 'energy', 'acousticness',
#        'instrumentalness', 'liveness', 'speechiness'],
#       dtype='object')

# %% [markdown]
# ### 2024 Data

# %%
data_2024.shape

# %%
data_2024.columns.tolist()

# %%
data_2024 = data_2024[[
    "Track",
    "Artist",
    "Spotify Streams",
    "ISRC",
    "All Time Rank",
    "Track Score"
]]

# %%
data_2024.head()

# %%
data_2024.info()

# %%
data_2024.isnull().sum()

# %% [markdown]
# #### Standardize column names in the 2024 dataset

# %%
data_2024.columns = (
    data_2024.columns
    .str.strip()
    .str.lower()
    .str.replace(" ", "_")
)

data_2024.columns

# %% [markdown]
# #### Rename the key identity columns in 2024 to match the other datasets

# %%
data_2024 = data_2024.rename(columns={
    "track": "track_name",
    "artist": "artist_names"
})

data_2024.columns

# %%
data_2024.dtypes

# %% [markdown]
# #### Convert spotify_streams and the other major numeric columns to a real numeric column

# %%
# Clean text columns
text_cols_2024 = ["track_name", "artist_names", "isrc"]

for col in text_cols_2024:
    data_2024[col] = data_2024[col].astype("string")

# Clean and convert spotify_streams safely
data_2024["spotify_streams"] = (
    data_2024["spotify_streams"]
    .astype("string")
    .str.replace(",", "", regex=False)
    .str.strip()
)

data_2024["spotify_streams"] = pd.to_numeric(data_2024["spotify_streams"], errors="coerce")

# Drop rows where spotify_streams is invalid/missing
data_2024 = data_2024.dropna(subset=["spotify_streams"])

# Convert spotify_streams to integer
data_2024["spotify_streams"] = data_2024["spotify_streams"].astype("int64")

# Convert remaining numeric columns
data_2024["all_time_rank"] = pd.to_numeric(data_2024["all_time_rank"], errors="coerce").astype("Int64")
data_2024["track_score"] = pd.to_numeric(data_2024["track_score"], errors="coerce")

# Check result
data_2024.info()

# %% [markdown]
# #### Check missing values in the key columns for all 3 datasets

# %%
print("2022")
print(data_2022[["track_name", "artist_names"]].isna().sum())

print("\n2023")
print(data_2023[["track_name", "artist_names"]].isna().sum())

print("\n2024")
print(data_2024[["track_name", "artist_names"]].isna().sum())

# %%
data_2024[data_2024["artist_names"].isna()][["track_name", "isrc"]]

# %%
data_2024 = data_2024.dropna(subset=["artist_names"])
data_2024[["track_name", "artist_names"]].isna().sum()

# %% [markdown]
# #### Standardize text formatting for song and artist names
# - remove leading/trailing spaces
# - convert to lowercase
# - remove double spaces

# %%
def clean_text(series):
    return (
        series.astype(str)
        .str.strip()
        .str.lower()
        .str.replace(r"\s+", " ", regex=True)
    )

data_2022["track_name"] = clean_text(data_2022["track_name"])
data_2022["artist_names"] = clean_text(data_2022["artist_names"])

data_2023["track_name"] = clean_text(data_2023["track_name"])
data_2023["artist_names"] = clean_text(data_2023["artist_names"])

data_2024["track_name"] = clean_text(data_2024["track_name"])
data_2024["artist_names"] = clean_text(data_2024["artist_names"])

# %% [markdown]
# #### Check for duplicate songs now that names are cleaned

# %%
print("2022 duplicates:", data_2022.duplicated(subset=["track_name", "artist_names"]).sum())
print("2023 duplicates:", data_2023.duplicated(subset=["track_name", "artist_names"]).sum())
print("2024 duplicates:", data_2024.duplicated(subset=["track_name", "artist_names"]).sum())

# %%
data_2022[data_2022.duplicated(subset=["track_name", "artist_names"], keep=False)] \
    .sort_values(["track_name", "artist_names"])

# %%
data_2023[data_2023.duplicated(subset=["track_name", "artist_names"], keep=False)] \
    .sort_values(["track_name", "artist_names"])

# %%
data_2024[data_2024.duplicated(subset=["track_name", "artist_names"], keep=False)] \
    .sort_values(["track_name", "artist_names"])

# %%
data_2022 = data_2022.drop_duplicates(subset=["track_name", "artist_names"], keep="first")
data_2023 = data_2023.drop_duplicates(subset=["track_name", "artist_names"], keep="first")
data_2024 = data_2024.drop_duplicates(subset=["track_name", "artist_names"], keep="first")

# %%
data_2022[data_2022.duplicated(subset=["track_name", "artist_names"], keep=False)] \
    .sort_values(["track_name", "artist_names"])

# %%
data_2023[data_2023.duplicated(subset=["track_name", "artist_names"], keep=False)] \
    .sort_values(["track_name", "artist_names"])

# %%
data_2024[data_2024.duplicated(subset=["track_name", "artist_names"], keep=False)] \
    .sort_values(["track_name", "artist_names"])

# %%
print("2022 duplicates:", data_2022.duplicated(subset=["track_name", "artist_names"]).sum())
print("2023 duplicates:", data_2023.duplicated(subset=["track_name", "artist_names"]).sum())
print("2024 duplicates:", data_2024.duplicated(subset=["track_name", "artist_names"]).sum())

# %%
print("2022 missing values:")
print(data_2022.isnull().sum())

print("\n2023 missing values:")
print(data_2023.isnull().sum())

print("\n2024 missing values:")
print(data_2024.isnull().sum())

# %% [markdown]
# - For 2022 nothing is missing so it's ok
# - For 2023, only `key` has missing values. key represents the musical key of the song (e.g., C#, A, D) and is not required for identifying songs or ranking popularity.
# - For 2024, `all_time_rank` has missing values. all_time_rank is not required for identifying songs or performing audio feature comparisons. Dropping rows based on all_time_rank would remove a large portion of the dataset (over 70%), which would significantly reduce the dataset size and bias the analysis. Therefore, all_time_rank is kept as NULL where missing.

# %%
data_2024.shape

# %%
data_2022.to_csv("CleanedData/cleaned_data_2022.csv", index=False)
data_2023.to_csv("CleanedData/cleaned_data_2023.csv", index=False)
data_2024.to_csv("CleanedData/cleaned_data_2024.csv", index=False)
